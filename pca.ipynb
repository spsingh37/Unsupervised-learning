# %% [markdown]
# # PCA and Eigenfaces
#
# In this notebook, we will test the convolution layer implementation from `layers.py` and then test the CNN implementation from `cnn.py` on the MNIST dataset.

# %% [markdown]
# ## Setup code
# Before getting started, we need to run some boilerplate code to set up our environment. You'll need to rerun this setup code each time you start the notebook. Let's start by checking whether we are using Python 3.10 or higher.

# %%
import sys
if sys.version_info[0] < 3:
    raise Exception("You must use Python 3")

if sys.version_info[1] < 11:
    print("Autograder will execute your code based on Python 3.11 environment. Please use Python 3.11 or higher to prevent any issues")
    print("You can create a conda environment with Python 3.11 like 'conda create --name eecs545 python=3.11'")
    raise Exception("Python 3 version is too low: {}".format(sys.version))
else:
    print("You are good to go")
# Out:
# You are good to go

# %% [markdown]
# First, run this cell load the [autoreload](https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html) extension. This allows us to edit `.py` source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Then, we run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
# import libraries
import math
import numpy as np
import matplotlib.pyplot as plt

# set figure size
plt.rcParams['figure.figsize'] = (5.0, 4.0)
plt.rcParams['font.size'] = 10
# %config InlineBackend.figure_format = 'retina'

# %%
from IPython.display import display_html, HTML

display_html(HTML('''
<style type="text/css">
  .instruction { background-color: yellow; font-weight:bold; padding: 3px; }
</style>
'''));
# Out:
# <style type="text/css">
#   .instruction { background-color: yellow; font-weight:bold; padding: 3px; }
# </style>

# %%
import pca
pca.hello_world()   # should print "Hello world!"

# %% [markdown]
# ## Load Data

# %% [markdown]
# Let's load the face images data. The dataset contains 2414 face grayscale images with size (48 x 42).

# %%
images = np.load("data/face.npy")
images.shape
# Out:
# (2414, 48, 42)

# %%
fig, ax = plt.subplots(figsize=(4, 3))
im = ax.imshow(images[0], cmap='gray');
fig.colorbar(im);

# %% [markdown]
# ## PCA

# %% [markdown]
# <p class="instruction">Now implement the `pca.train_PCA` function.</p> This function should return the transform matrix $U$ and eigenvalues $\lambda = (\lambda_1, \cdots, \lambda_m)$ such that $u_1$ is the first principal component with eigenvalue $\lambda_1$, and so on. Training PCA on this particular dataset will take some time; for instance, around 10 seconds on a laptop.

# %%
# Convert images to a 2D matrix
X = images.reshape([images.shape[0], -1])

# %%
# %%time
U, eigenvalues = pca.train_PCA(X)
# Out:
# CPU times: user 15min 44s, sys: 1min 4s, total: 16min 48s
# Wall time: 3min 50s

# %% [markdown]
# ## Eigenvalues

# %% [markdown]
# <span>Lets print out the first few eigenvalues and draw a plot of eigenvalues.</span>. Do not forget using log scale for the y-axis (e.g., `ax.set_yscale('log')`)

# %%
print(eigenvalues[:10])
# Out:
# [2718207.40988722 2610783.99363041  365363.88318788  211062.3677067
#   110557.40979615  104672.41713697   78480.41139035   67004.29456699
#    52571.01809635   49176.70124035]

# %%
fig, ax = plt.subplots()

#######################################################################
ax.plot(eigenvalues)
ax.set_yscale('log')
#######################################################################

# %% [markdown]
# ## Eigenvectors (Eigenfaces)

# %% [markdown]
# Now lets <span class="instruction">make a 2x5 array of plots</span> showing the first 9 eigenvalues as well as the mean of images as the first principal component. We'll use `"jet"` color map (see [matplotlib colormap](https://matplotlib.org/stable/tutorials/colors/colormaps.html) documentation) to visualize the difference more clearly. Also note that each eigenface may have different colormap scale; optionally, you may also want to add colorbars to visualize the scale of colormaps.

# %%
fig, axes = plt.subplots(2, 5, figsize=(12, 4))

#######################################################################
eigenfaces = np.zeros([10, 48, 42])
eigenfaces[0, ...] = np.mean(images, axis=0) / 255.0

for i in range(9):
    eigenfaces[i + 1, ...] = U[:, i].reshape(48, 42)
    
for i in range(10):
    im = axes.flat[i].imshow(eigenfaces[i], cmap='jet')
    fig.colorbar(im)
#######################################################################

fig.tight_layout()

# %% [markdown]
# ## Total Variance

# %% [markdown]
# <span class="instruction">Lets print the total variance</span>: feel free to create more cells to do necessary computation.

# %%
cumul_ev = np.cumsum(eigenvalues)
variance_por = cumul_ev / cumul_ev[-1]

index_1 = (variance_por >= 0.95).nonzero()[0][0] + 1
index_2 = (variance_por >= 0.99).nonzero()[0][0] + 1
print(index_1, 1 - index_1 / 48/42)
print(index_2, 1 - index_2 / 48/42)
# Out:
# 43 0.9786706349206349
# 167 0.9171626984126984
